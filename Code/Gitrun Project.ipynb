# %%
# !git clone -b main https://github.com/babankbro/Tugboat.git
# Out:
# Cloning into 'Tugboat'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 225 (delta 121), reused 197 (delta 93), pack-reused 0 (from 0)
# Receiving objects: 100% (225/225), 5.59 MiB | 8.74 MiB/s, done.
# Resolving deltas: 100% (121/121), done.

# %%
# %cd Tugboat
# Out:
# /content/Tugboat

# %%
# !python  CodeVS/main.py
# Out:
# 26 25
# TravelHelper new
# TravelHelper initialized
# DEBUG_BARGE o1 19 0
# BRING_DOWN -------------------------------
# END_DOWN -------------------------------
# Rotation barge remain: 19
# Tugboat is not ready tbs3 o1 2025-01-16 18:00:00 2025-01-18 08:00:00
# Tugboat Riverrrrrrr ##########################################################
# {'tugboat_id': 'tbr1', 'order_id': None, 'start_datetime': datetime.datetime(2025, 1, 10, 8, 0), 'end_datetime': datetime.datetime(2025, 1, 10, 8, 0), 'river_km': 20.0, 'water_status': <WaterBody.RIVER: 'RIVER'>, 'location': (13.5448563990692, 100.585120135179), 'station_id': 's2', 'barge_infos': []}
# Tugboat Riverrrrrrr ##########################################################
# ...
